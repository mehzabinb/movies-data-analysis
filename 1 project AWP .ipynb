# %%
# movies data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("movies.csv") 
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
df.tail(10)
# Out:
#      star_rating                                            title  \
# 969          7.4                              Law Abiding Citizen
# 970          7.4                                      Wonder Boys
# 971          7.4                               Death at a Funeral
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 969              R      Crime       109
# 970              R      Drama       107
# 971              R     Comedy        90
# 972          NC-17      Drama       112
# ...

# %%
df.info()    
#there are 980 entries in the dataset,having 6 columns & 980 rows. starting index from 0 to 980
#There are no-null values in entire dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
df.shape
# Out:
# (979, 6)

# %%
df.columns  #14 columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
df.describe()
# star_rating and duration are diffrent
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
df['star_rating'].hist(color='Green')           # star_rating
# Out:
# <AxesSubplot:>

# %%
df['duration'].hist(color='yellow')                         # duration time
# Out:
# <AxesSubplot:>

# %%
mstar_rating=df['star_rating'].mean()
mstar_rating=df['star_rating'].median()

sns.distplot(df['star_rating'])
plt.axvline(mstar_rating,color='r')
plt.axvline(mstar_rating,color='y')
plt.grid(True)
plt.show()

# %%
#Fetching order priority

# %%
sns.countplot(df['star_rating']) 
# 7.6 has highest count followed by 7.8>7.7>7.5
# 7.7 and 7.5 have very minor difference and both are above 100
# 8.2 and 7.4 have very minor difference and both are above 40
# Out:
# <AxesSubplot:xlabel='star_rating', ylabel='count'>

# %%
rates=df.groupby('star_rating').sum()['duration'].reset_index()
rates.sort_values('duration',ascending=False)
#All the items arranged according to their duration.
# 14548 is the highest duration and there star_rating is 7.6
# 142 is the lowest duration but their star rating is higest 9.3
# Out:
#     star_rating  duration
# 2           7.6     14548
# 4           7.8     13777
# 3           7.7     13364
# 1           7.5     12549
# 7           8.1     12360
# 6           8.0     11719
# 5           7.9      8934
# 8           8.2      6450
# 9           8.3      5683
# 0           7.4      5563
# 10          8.4      4828
# 11          8.5      3110
# 12          8.6      1763
# 13          8.7      1405
# 15          8.9       946
# 14          8.8       771
# 17          9.1       200
# 18          9.2       175
# 16          9.0       152
# 19          9.3       142

# %%
plt.figure(figsize=(10,5))
plt.plot(rates['star_rating'],rates['duration'])
plt.xticks(rotation='vertical',size=8)
plt.show()

# %%
# Fetching the most preffered

# %%
plt.figure(figsize=(15,6))
sns.lineplot(df['star_rating'],df['duration'])
plt.grid(True)
plt.show()
